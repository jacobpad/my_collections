# %% [markdown]
# # DS12 Lectures

# %% [markdown]
# - [LS2001 FT Orientation](https://youtu.be/2xw94NWCkqs)
# - [LS2001 2nd Orientation 1 24 2020  DS12, DSPT5, iOS14, iOSPT5, WEB28, WEBPT15](https://youtu.be/ebutqFjtRu0)

# %% [markdown]
# ## Unit 1 - [DS - Statistics Fundamentals](https://learn.lambdaschool.com/ds/sprint/rec2a82u6kWqXEB45)

# %% [markdown]
# ### Sprint 1

# %% [markdown]
# - [Exploratory Data Analysis](https://learn.lambdaschool.com/ds/module/rec81pljcvgboWB6U/) - [Lecture](https://youtu.be/FPanC0bYTls)
# - [Make Features](https://learn.lambdaschool.com/ds/module/recD0PnM64cmU06N1/) - [Lecture](https://youtu.be/CYuRtxWvsR4)
# - [Join and Reshape Data](https://learn.lambdaschool.com/ds/module/recLMyOUPqsW4wm90/) - [Lecture](https://youtu.be/Ryhc-WZuj5A)
# - [Make Explanatory Visualizations](https://learn.lambdaschool.com/ds/module/recK7pBbrxfDphtSd/) - [Lecture](https://youtu.be/n7jBFqVI6nc)
# ---
# - [Sprint 1 Thursday Q&A - DS12](https://youtu.be/BT6P1wvTT48)

# %% [markdown]
# ### Sprint 2 - [DS - Statistics Fundamentals](https://learn.lambdaschool.com/ds/sprint/recorynMW4uJ05ASZ)

# %% [markdown]
# - [Hypothesis Testing (t-tests)](https://learn.lambdaschool.com/ds/module/reca7wkH2otMJwYwL) - [Lecture](https://youtu.be/C8lWCi9uYAs)
# - [Hypothesis Testing (t-tests)](https://learn.lambdaschool.com/ds/module/reca7wkH2otMJwYwL) - [DS9 Lecture](https://youtu.be/zhPGoHZo5i4)
#   - [Sprint 2 Module 1 Review with Ryan Allred](https://youtu.be/QOPvS6QGb9Y)
#   - [t-Test Overview](https://youtu.be/0D_xGoSBe4Y)
# - [Hypothesis Testing (chi-square tests)](https://learn.lambdaschool.com/ds/module/recSyGHdvxNJxWob7) - [Lecture](https://youtu.be/J6F_KadAmOY)
# - [Confidence Intervals](https://learn.lambdaschool.com/ds/module/reczBCaWiVZyBGCCT) - [Lecture](https://youtu.be/r038lU3tRds)
# - [Bayesian Statistics](https://learn.lambdaschool.com/ds/module/recedjanLBpQxIc2r) - [Lecture](https://youtu.be/3PaEsj9xY9U)
# ---
# - [Sprint 2 Statistics Q&A with Ryan Allred](https://youtu.be/IeUej5qf15U)
# - [DS12 Wednesday Statistics Q&A with Ryan Allred](https://youtu.be/dgeO2E83MRk)
# - [DS12 Sprint 2 Thursday Q&A with Ryan Allred](https://youtu.be/zBigTY9_Fzk)

# %% [markdown]
# ### Sprint 3 - [Linear Algebra](https://learn.lambdaschool.com/ds/sprint/recr0kuGaz6Uf4axZ)

# %% [markdown]
# - [Vectors and Matrices](https://learn.lambdaschool.com/ds/module/rec6oDxWOTL1e9Ii3/) - [Lecture](https://youtu.be/nvLOt6a94ok)
# - [Intermediate Linear Algebra](https://learn.lambdaschool.com/ds/module/recyR22S2HMD6bYAO/) - [Lecture](https://youtu.be/dyRbEFDkOAA)
# - [Dimensionality Reduction Techniques](https://learn.lambdaschool.com/ds/module/rec0pSWqkfdxJv6eC/) - [Lecture](https://youtu.be/C385vv3oqaw)
# - [Clustering](https://learn.lambdaschool.com/ds/module/recnLDoPD0eLGPq1z/) - [Lecture](https://youtu.be/bM9zSARYw7g)
# ---
# - [DS12 Thursday Linear Algebra Q&A with Ryan Allred](https://youtu.be/nZJ_85frQ4k)
# - [Cross Product and Dot Product: Visual explanation](https://www.youtube.com/watch?v=h0NJK4mEIJU)

# %% [markdown]
# ## [Unit 1 Build Week Projects DS12](https://youtu.be/nPz9EUCKrSU)

# %% [markdown]
# ## Unit 2 - [DS - Predictive Modeling](https://learn.lambdaschool.com/ds/sprint/recwXzAICs5dfcBw1)

# %% [markdown]
# ### Sprint 1 - [Linear Models](https://learn.lambdaschool.com/ds/sprint/recwXzAICs5dfcBw1)

# %% [markdown]
# - [Regression 1](https://learn.lambdaschool.com/ds/module/recJgCSqdWPoynqv6/) - [Lecture](https://youtu.be/rsubwNRqHKw)
# - [Regression 2](https://learn.lambdaschool.com/ds/module/recXqQFbsskJBNPlX/) - [Lecture](https://youtu.be/yBMVAXX0WyI)
# - [Ridge Regression](https://learn.lambdaschool.com/ds/module/recVGCrPKv4cL9tEF/) - [Lecture](https://youtu.be/lPaHTmqotHs)
# - [Logistic Regression](https://learn.lambdaschool.com/ds/module/recx5tdEUQYJZ5kHZ/) - [Lecture](https://youtu.be/Wz7Blt3bZi4)

# %% [markdown]
# [Seminar on OOP!](https://youtu.be/CcGzF6sPPKw)

# %% [markdown]
# ### Sprint 2 - [Kaggle Challenge](https://learn.lambdaschool.com/ds/sprint/rece0tbcBVl01xfq6)

# %% [markdown]
# - [Decision Trees](https://learn.lambdaschool.com/ds/module/rec1RD21cWVUPdnfr/) - [Lecture](https://youtu.be/wy490lecFX0)
# - [Random Forests](https://learn.lambdaschool.com/ds/module/recNrVqWhAs5YMK0p/) - [Lecture](https://youtu.be/SqGQa_h28Ig)
# - [Cross-Validation](https://learn.lambdaschool.com/ds/module/recH0NmaPa83iXGWQ/) - [Lecture](https://youtu.be/VQbZluiH_rU)
# - [Classification Metrics](https://learn.lambdaschool.com/ds/module/recQGaK0cy4n5sZ5i/) - [Lecture](https://www.youtube.com/watch?v=a5aT6Gl6tE4&feature=youtu.be)
# ---
# - [ds12 Q&A](https://youtu.be/w246q3PJsC8)

# %% [markdown]
# ### Sprint 3 - [Applied Modeling](https://learn.lambdaschool.com/ds/sprint/recgPpsKlD7tjQxoB)

# %% [markdown]
# - [Define ML problems](https://learn.lambdaschool.com/ds/module/recvDZb2pBkbnV1FM/) - [Lecture](https://youtu.be/bXj6vZ97XBk)
# - [Wrangle ML Datasets](https://learn.lambdaschool.com/ds/module/recFDRggWTWsaZb5w/) - [Lecture](https://youtu.be/yrtFP707OUA)
# - [Wrangle ML Datasets](https://learn.lambdaschool.com/ds/module/recFDRggWTWsaZb5w/) - [Lecture DS10](https://youtu.be/9cHT2AoKFPs)
# - [Permutation & Boosting](https://learn.lambdaschool.com/ds/module/reccfUja14MvXcHOk/) - [Lecture](https://youtu.be/rCXLdx5E19s)
# - [Model Interpretation](https://learn.lambdaschool.com/ds/module/recMvFC7ZYtsxnCYU/) - [Lecture](https://youtu.be/2zCAZYxa_IA)
# ---
# - [Web scraping](https://youtu.be/Q0GL2pAV4Ns)
# - [Lambda School DS Brown Bag - Austin Lasseter, Plotly Dash](https://youtu.be/tcF4XPAq7rE)

# %% [markdown]
# ## [DS12 Unit 2 Projects Presentations](https://youtu.be/wW4UGB83MO0)

# %% [markdown]
# ## Unit 3 - [DS - Data Engineering](https://learn.lambdaschool.com/ds/sprint/recA7O3QeO8AQxsxE)

# %% [markdown]
# ### Sprint 1 - [Software Engineering and Reproducible Research](https://learn.lambdaschool.com/ds/sprint/recA7O3QeO8AQxsxE)

# %% [markdown]
# - [Python Modules, Packages, and Environments](https://learn.lambdaschool.com/ds/module/recwEPR24pu5LCnA5/) - [Lecture](https://youtu.be/tc-IxSOTYhQ)
# - [OOP, Code Style, and Reviews](https://learn.lambdaschool.com/ds/module/recqeF16aJfb1UTWF/) - [Lecture](https://youtu.be/8awlJH0yEmw)
# - [Containers and Reproducible Builds](https://learn.lambdaschool.com/ds/module/recLjxZbBV3Jmrj2T/) - [Lecture](https://youtu.be/vGkOCF-InqY)
# - [Software Testing, Documentation, and Licensing](https://learn.lambdaschool.com/ds/module/recq9eVVCzZpgeH58/) - [Lecture](https://youtu.be/26ewLvoPDcs)
# ---
# - [local setup qa](https://youtu.be/Q1W1uLEv7h8)
# - [Docker](https://youtu.be/nrzxKL4bsLI)
# - [Book on Docker Basics](https://resources.sei.cmu.edu/asset_files/Presentation/2017_017_001_497378.pdf)
# - [Online Interactive Browser-Based Scenarios for Docker](https://www.katacoda.com/courses/docker/)

# %% [markdown]
# ### Sprint 2 - [SQL and Databases](https://learn.lambdaschool.com/ds/sprint/recV8wEgPdwWmUInW)

# %% [markdown]
# - [Introduction to SQL](https://learn.lambdaschool.com/ds/module/recmwiPQG5zueKFCG/) - [Lecture](https://youtu.be/9CLvZxab0mk)
# - [SQL for Analysis](https://learn.lambdaschool.com/ds/module/recSdx6IFkDxqgxGb/) - [Lecture](https://youtu.be/gRgaGsLlsz0)
# - [NoSQL and Document-Oriented Databases](https://learn.lambdaschool.com/ds/module/rec3JRFsRH2yeALwS/) - [Lecture](https://youtu.be/2mkr1A-yrCA)
# - [ACID and Database Scalability Trade-offs](https://learn.lambdaschool.com/ds/module/rec9c9nW20Sn6TBAO/) - [Lecture](https://youtu.be/a0copfwq_Sk)

# %% [markdown]
# ### Sprint 3 - [3.  Productization and Cloud](https://learn.lambdaschool.com/ds/sprint/recvbdRfBNCqSB4hd)

# %% [markdown]
# - [Web Application Development with Flask](https://learn.lambdaschool.com/ds/module/recKGvwkPaEsfnwDL/) - [Lecture](https://youtu.be/kGcU5QmLJIQ)
# - [Consuming Data from an API](https://learn.lambdaschool.com/ds/module/recVFIbE3mpjpVGrj/) - [Lecture part 1](https://youtu.be/BmmLOfAZgoo) [part 2](https://youtu.be/n-PJs1Pv--M)
# - [Adding Data Science to a Web Application](https://learn.lambdaschool.com/ds/module/recZOXl2H7Bbd1LMK/) - [Lecture](https://youtu.be/XeNYBDJdSao)
# - [Web Application Deployment](https://learn.lambdaschool.com/ds/module/recpPYQdaOmZdBSYq/) - [Lecture](https://youtu.be/6QWksoc8mvk)
# ---
# - [4.5 hour Study session with Brandon Mulas](https://youtu.be/eVwn4eOxiaI)

# %% [markdown]
# ## Unit 4 - [DS - Machine Learning](https://learn.lambdaschool.com/ds/sprint/recBptZbfRxhQFbIE)

# %% [markdown]
# ### Sprint 1 - [Natural Language Processing](https://learn.lambdaschool.com/ds/sprint/recBptZbfRxhQFbIE)

# %% [markdown]
# - [Natural Language Processing - Introduction](https://learn.lambdaschool.com/ds/module/rec5r3BWhwU0xnsUg/) - [Lecture](https://youtu.be/gvImQJTrJps)
# - [Vector Representations](https://learn.lambdaschool.com/ds/module/rec0O4tJizjI1C6EA/) - [Lecture](https://youtu.be/s6evnzZfmas)
# - [Document Classification](https://learn.lambdaschool.com/ds/module/reciZkZiLkmYujcMp/) - [Lecture](https://youtu.be/Ba5HLEaQHXI)
# - [Topic Modeling](https://learn.lambdaschool.com/ds/module/recbYIWnPYs2J4AWC/) - [Lecture](https://youtu.be/0JytSm_5D38)

# %% [markdown]
# ### Sprint 2 - [Neural Network Foundations](https://learn.lambdaschool.com/ds/sprint/recUR5N8Vo1lO7gvr)

# %% [markdown]
# - [Perceptrons](https://learn.lambdaschool.com/ds/module/recrb8xiWVfMFRy9Z/) - [Lecture](https://youtu.be/1XDjwR7xhOE)
# - [Gradient Descent and Backpropagation](https://learn.lambdaschool.com/ds/module/recU22sI50giR3dES/) - [Lecture](https://youtu.be/sY2PwFo01O4)
# - [Neural Network Frameworks](https://learn.lambdaschool.com/ds/module/recIQiPJwXIYNUkAI/) - [Lecture](https://youtu.be/_o00J7XKSw8)
# - [Hyperparameter Tuning](https://learn.lambdaschool.com/ds/module/recTADQcdez9Xv274/) - [Lecture](https://youtu.be/ZBK0pAMOA4U)

# %% [markdown]
# ### Sprint 3 - [Major Neural Network Architectures](https://learn.lambdaschool.com/ds/sprint/rec5inpL5t6W30CFH)

# %% [markdown]
# - [Recurrent Neural Networks and LSTM](https://learn.lambdaschool.com/ds/module/recFyZHPjJq946PTY/) - [Lecture](https://www.youtube.com/watch?v=GzlemTdFTTI&feature=youtu.be)
# - [Convolutional Neural Networks](https://learn.lambdaschool.com/ds/module/recqHJdPj1QXiVpAP/) - [Lecture](https://youtu.be/O-zIRS8JJxE)
# - [AutoEncoders and Recommendation Systems](https://learn.lambdaschool.com/ds/module/recKXiakNPgwC4WWh/) - [Lecture](https://youtu.be/k-IoETHl2nY)
# - [Artificial General Intelligence and The Future](https://learn.lambdaschool.com/ds/module/rec1Q9iO0EbI3sUVE/) - [Lecture](https://youtu.be/zznxAR6AP4I)

# %% [markdown]
# ![CLI cheats](https://www.git-tower.com/blog/media/pages/posts/command-line-cheat-sheet/1073300074-1586415841/command-line-cheat-sheet-large01.png)

# %% [markdown]
# ![Esssential Python](https://i.pinimg.com/originals/e1/d7/b7/e1d7b768b72c2209325d90960581bd6b.jpg)

# %% [markdown]
# ![Git](https://rubygarage.s3.amazonaws.com/uploads/article_image/file/599/git-cheatsheet-5.jpg)
